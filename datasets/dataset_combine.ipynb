# %%
import numpy as np        # For numerical operations
import pandas as pd       # For data manipulation and analysis
import matplotlib.pyplot as plt  # For data visualization
# %matplotlib inline

# Importing WordCloud for text visualization
from wordcloud import WordCloud

# Importing NLTK for natural language processing
import nltk
from nltk.corpus import stopwords    # For stopwords


# Downloading NLTK data
nltk.download('stopwords')   # Downloading stopwords data
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv(
    '/content/drive/MyDrive/Project/dataset/completeSpamAssassin.csv',
    encoding='latin1')[['Body', 'Label']]
df2 = pd.read_csv(
    '/content/drive/MyDrive/Project/dataset/enronSpamSubset.csv',
    encoding='latin1')[['Body', 'Label']]
df3 = pd.read_csv(
    '/content/drive/MyDrive/Project/dataset/lingSpam.csv',
    encoding='latin1')[['Body', 'Label']]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6046 entries, 0 to 6045
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Body    6045 non-null   object
#  1   Label   6046 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 94.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Body    10000 non-null  object
#  1   Label   10000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 156.4+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2605 entries, 0 to 2604
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Body    2605 non-null   object
#  1   Label   2605 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 40.8+ KB

# %%
df1['source'] = 'SpamAssassin'
df2['source'] = 'Enron'
df3['source'] = 'LingSpam'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6046 entries, 0 to 6045
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Body    6045 non-null   object
#  1   Label   6046 non-null   int64
#  2   source  6046 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 141.8+ KB

# %%
df1[df1['Body'].isnull()] 

df1.dropna(subset=['Body'], inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6045 entries, 0 to 6045
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Body    6045 non-null   object
#  1   Label   6045 non-null   int64
#  2   source  6045 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 188.9+ KB

# %%
combined_df = pd.concat([df1, df2, df3], ignore_index=True)

combined_df = combined_df.dropna(subset=['Body'])

combined_deduped_df = combined_df.drop_duplicates(subset=['Body'], keep='first')

combined_deduped_df.to_csv('spam.csv', index=False)

print(f"Full dataset shape: {combined_df.shape}")

print(f"Deduplicated dataset shape: {combined_deduped_df.shape}")
# Out:
# Full dataset shape: (18650, 3)
# Deduplicated dataset shape: (17570, 3)
